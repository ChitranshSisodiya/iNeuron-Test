# %% [markdown]
# Phython Basics

# %%
4%2
# Out:
# 0

# %%
5//2
# Out:
# 2

# %%
7//2
# Out:
# 3

# %%
# Use Bodmas
5+6*2
# Out:
# 17

# %%
type(5/2)
# Out:
# float

# %%
# Boolean Operation
True or False
# Out:
# True

# %%
True and False
# Out:
# False

# %%
# Strings
# Never use reserved keyword like str, int,fload etc.
a="Chitransh"
a
# Out:
# 'Chitransh'

# %%
str(a)
# Out:
# 'Chitransh'

# %%
str1="A good Boy"
str2="A bad Boy"
str1+" "+str2
# Out:
# 'A good Boy A bad Boy'

# %%
name=input("Enter Your Name ")
print(name)
# Out:
# Enter Your Name cjh
# cjh

# %%
a=int(input("enter a  number "))
b=int(input())
print('The output Is ',a+b)
# Out:
# enter a  number5
# 6
# The output Is  11

# %%
first_name=input("Enter First Name ")
last_name=input("Enter Last Name ")
print("My First Name is {} and Last Name is {}".format(first_name,last_name))
print("My First Name is {firstname} and Last Name is {lastname}".format(lastname=last_name,firstname=first_name))
# Out:
# Enter First Name sad
# Enter Last Name hgf
# My First Name is sad and Last Name is hgf
# My First Name is sad and Last Name is hgf

# %% [markdown]
# Variable Dynamic Typing

# %%
a=10
type(a)
# Out:
# int

# %%
a="harsh"
type(a)
# Out:
# str

# %%
# Conditional Statement
a=int(input("enter a  number "))
b=int(input("enter a  number "))
c=a-b
if c<0 :
    print("b is greater then a")
else :
    print("a is greater then b")
# Out:
# enter a  number 45
# enter a  number 56
# b is greater then a

# %% [markdown]
# # Data Structures
# 1.List
# 2.Tuples
# 3.Dictionary
# 4.String
# 5.Sets

# %%
#String Is Immutable
#string does not support item assignment
